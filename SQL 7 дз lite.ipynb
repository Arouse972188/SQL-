# %%
# !pip install psycopg2
# !pip install plotly.express
import random
import pandas as pd
import numpy as np
import psycopg2
from IPython.display import HTML
import matplotlib.pyplot as plt
import sqlite3

# %%
conn = sqlite3.connect('task1_7.db')
c = conn.cursor()

# %%
request = "CREATE TABLE TT(a int, b int, c int)"
c.execute(request)
tables = c.fetchall()

# %%
c.execute("SELECT * from TT")
results = c.fetchall()
results
# Out:
# []

# %%
DB_HOST = '52.157.159.24'
DB_USER = 'student23'
DB_USER_PASSWORD = 'student23_password'
DB_NAME = 'sql_ex_for_student23'

conn_ps2 = psycopg2.connect(host=DB_HOST, user=DB_USER, password=DB_USER_PASSWORD, dbname=DB_NAME)

# %%
request = """
select * 
from table2 
"""
df = pd.read_sql_query(request, conn_ps2)

# %%
df.to_sql('table5',conn) 
c.execute("SELECT * from table5") 
results = c.fetchall()
results
# Out:
# [(0, 881, 171, 338),
#  (1, 697, 736, 925),
#  (2, 789, 886, 35),
#  (3, 272, 216, 912),
#  (4, 587, 768, 375),
#  (5, 783, 854, 105),
#  (6, 668, 79, 809),
#  (7, 372, 517, 729),
#  (8, 953, 224, 410),
#  (9, 409, 616, 843),
#  (10, 28, 497, 14),
#  (11, 366, 195, 750),
#  (12, 291, 984, 635),
#  (13, 326, 256, 851),
#  (14, 237, 843, 619),
#  (15, 612, 625, 472),
#  (16, 717, 294, 552),
#  (17, 526, 666, 68),
#  (18, 255, 619, 293),
#  (19, 665, 28, 909),
#  (20, 508, 55, 406),
#  (21, 522, 421, 601),
#  (22, 271, 712, 585),
#  (23, 906, 38, 841),
#  (24, 757, 275, 684),
#  (25, 376, 887, 309),
#  (26, 848, 604, 603),
#  (27, 399, 130, 269),
#  (28, 468, 385, 888),
#  (29, 761, 50, 915),
#  (30, 670, 557, 971),
#  (31, 76, 79, 392),
#  (32, 677, 350, 104),
#  (33, 262, 256, 141),
#  (34, 103, 13, 417),
#  (35, 787, 389, 304),
#  (36, 96, 237, 908),
#  (37, 699, 636, 38),
#  (38, 968, 104, 423),
#  (39, 856, 865, 473),
#  (40, 771, 535, 30),
#  (41, 742, 611, 109),
# ...

# %%
n=pd.DataFrame(results)
# Out:
#          0    1    2    3
# 0        0  881  171  338
# 1        1  697  736  925
# 2        2  789  886   35
# 3        3  272  216  912
# 4        4  587  768  375
# ...    ...  ...  ...  ...
# 9995  9995  699  915  236
# 9996  9996  662  859  803
# 9997  9997  713  884  905
# 9998  9998  849  368  574
# 9999  9999  112  411  732
#
# [10000 rows x 4 columns]

# %%
plt.figure(figsize=(10,5))
plt.hist(n, bins=3, edgecolor='black')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
